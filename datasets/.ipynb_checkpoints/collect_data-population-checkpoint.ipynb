# %% [markdown]
# # Collect data
#
# ### Cesus dot gov

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import json
import time
import csv

# Import API key
from config import census_api_key

# %% [markdown]
# ### NAICS codes table
#
#     2012~ : there are sub categories
#     Before 2012, the number of employeements is available in total, no sub categories.
#
#     For sub category bar chart, data from 2012 will be displayed.
#
#     For timeline chart, data from 1986, number of employ will be displayed.

# %%
# NAICS2017 codes and labels:  CBP data of 2017~2018 refer to NICS2017 table for business labels
url = "https://api.census.gov/data/2018/cbp/variables/NAICS2017.json"
result = requests.get(url).json()
naics_items = result["values"]["item"]
naics2017 = { ky: naics_items[ky] for ky in naics_items.keys() if len(ky)==2}

# NAICS2012 codes and labels : CBP data of 2012~2016 refer to NICS2012 table for business labels
url = "https://api.census.gov/data/2016/cbp/variables/NAICS2012.json"
result = requests.get(url).json()
naics_items = result["values"]["item"]
naics2012 = { ky: naics_items[ky] for ky in naics_items.keys() if len(ky)==2}

# Write the tables to json files
with open("naics2017.json", "w") as outfile:  
    json.dump(naics2017, outfile)

with open("naics2012.json", "w") as outfile:  
    json.dump(naics2012, outfile)

# %% [markdown]
# ### County codes and names
#
# * From census,

# %%
# NC County names and codes from CENSUS
url = "https://api.census.gov/data/2018/cbp?get=NAME&for=county:*&in=state:37&key="+census_api_key
result = requests.get(url).json()

# %%
df = pd.DataFrame(result, columns=result[0])
county_df=df.drop(0).drop(["state"], axis=1)
county_df.head()
# Out:
#                                NAME county
# 1     Greene County, North Carolina    079
# 2    Haywood County, North Carolina    087
# 3   Mitchell County, North Carolina    121
# 4     Chowan County, North Carolina    041
# 5  Cleveland County, North Carolina    045

# %%
# Write the table to json file
#county_df.to_json("county_codes.json", orient="table", index=False)
county_df.to_json("county_codes.json", orient="columns")

# %% [markdown]
# * From NC map GeoJSON

# %%
# Save the county properties from NC map geojson to a json file
def retrieve_county_Geojson():

    response = requests.get("https://opendata.arcgis.com/datasets/d192da4d0ac249fa9584109b1d626286_0.geojson")

    # Get county codes

    json_data = response.json()

    ctdata = json_data['features']
    ctarray = []
    for ct in ctdata:
        ctarray.append(ct['properties'])
    with open("county_codes2.json", "w") as ft:
        json.dump(ctarray, ft)

# %% [markdown]
# ## Combine the county codes

# %%
# Geojson codes
gct_df = pd.read_json("county_codes2.json")
gct_n_df = gct_df[['CountyName', 'SAP_CNTY_NBR', 'CNTY_NBR']]
gct_n_df.head()
# Out:
#   CountyName  SAP_CNTY_NBR  CNTY_NBR
# 0     Camden            15        14
# 1      Gates            37        36
# 2    Iredell            49        48
# 3     Wilkes            97        96
# 4      Union            90        89

# %%
# Census codes
cct_df = pd.read_json("county_codes.json")
cct_df.head()
# Out:
#                                NAME  county
# 1     Greene County, North Carolina      79
# 2    Haywood County, North Carolina      87
# 3   Mitchell County, North Carolina     121
# 4     Chowan County, North Carolina      41
# 5  Cleveland County, North Carolina      45

# %%
name = [ nm.split()[0]  for nm in cct_df['NAME'].values ]
cct_df['CountyName'] = name
cct_df.head()
# Out:
#                                NAME  county CountyName
# 1     Greene County, North Carolina      79     Greene
# 2    Haywood County, North Carolina      87    Haywood
# 3   Mitchell County, North Carolina     121   Mitchell
# 4     Chowan County, North Carolina      41     Chowan
# 5  Cleveland County, North Carolina      45  Cleveland

# %%
combined = pd.merge(gct_n_df, cct_df, on='CountyName', how='inner')
combined.rename(columns={"CNTY_NBR" : "Geo_NBR", "county":"Census_NBR"}, inplace=True)
combined.head()
# Out:
#   CountyName  SAP_CNTY_NBR  Geo_NBR                            NAME  \
# 0     Camden            15       14   Camden County, North Carolina
# 1      Gates            37       36    Gates County, North Carolina
# 2    Iredell            49       48  Iredell County, North Carolina
# 3     Wilkes            97       96   Wilkes County, North Carolina
# 4      Union            90       89    Union County, North Carolina
#
#    Census_NBR
# 0          29
# 1          73
# 2          97
# 3         193
# 4         179

# %%
new_df = combined[['CountyName', 'Geo_NBR', 'Census_NBR']]
new_df.set_index('CountyName', inplace=True)
new_df.head()
# Out:
#             Geo_NBR  Census_NBR
# CountyName
# Camden           14          29
# Gates            36          73
# Iredell          48          97
# Wilkes           96         193
# Union            89         179

# %%
#  new_df.to_dict('index')
new_df.to_json("combined_county_codes.json", orient="index")

# %% [markdown]
# ## Set variables, url for API calls
#
# * API queries -- info for all counties

# %%
# Check the NAICS codes which have only 2 digits

with open("naics2017.json", "r") as fileobj:  
    naics2017 = json.load(fileobj)

print(naics2017.keys())

with open("naics2012.json", "r") as fileobj:  
    naics2012 = json.load(fileobj)

print(naics2012.keys())
# Out:
# dict_keys(['00', '11', '21', '22', '23', '42', '51', '52', '53', '54', '55', '56', '61', '62', '71', '72', '81', '95', '99'])
# dict_keys(['00', '11', '21', '22', '23', '42', '51', '52', '53', '54', '55', '56', '61', '62', '71', '72', '81', '95', '99'])

# %%
## Set a naics code query to restrict the API call only for 2-digit business codes
def set_naics_query(year):
    
    # The NAICES codes for higher level business
    NAICS_codes = ['00', '11', '21', '22', '23', '42', '51', '52', '53', '54', '55', '56', '61', '62', '71', '72', '81', '95', '99']
    code_query = ""
    for code in NAICS_codes:
        if (year >= 2017):
            code_query += f'&NAICS2017={code}'
        elif (year >= 2012):
            code_query += f'&NAICS2012={code}'
    return code_query


## Set a url for given year to retrieve employee data for all counties.
def set_url(year):
    
    cbp_url = f'https://api.census.gov/data/{year}/cbp?get='
    
    ## The quary variables vary in years
    if (year >= 2017):
        variables = "NAME,EMP"
    elif (year >= 2012):
        variables = "GEO_TTL,EMP"
    elif (year > 2007):
        variables = "NAICS2007_TTL,GEO_TTL,EMP"
    elif (year > 2002):
        variables = "NAICS2002_TTL,GEO_TTL,EMP"
    elif (year > 1997):
        variables = "NAICS1997_TTL,GEO_TTL,EMP"
    else:
        variables = "GEO_TTL,EMP"
    
    url = cbp_url+variables+"&for=county:*&in=state:37&key="+census_api_key
    
    # From 2012, there are subcategories upto 2~6 digits in NAICS codes. We collect only 2 digits codes.
    if (year >= 2012):
        url += set_naics_query(year)
    
    return url

# %% [markdown]
# ### Perform API calls
#
# * By year, for given year, collect data for all counties

# %%
url = set_url(2012)

try:
    response = requests.get(url)
    print(response)
    census_data = response.json()
    #print(json.dumps(census_data, indent=4))
except:
    print(f"Found error")
# Out:
# <Response [200]>

# %%
df = pd.DataFrame(census_data, columns=census_data[0])
emp_df=df.drop(0).drop("state",axis=1)
emp_df.head()
# Out:
#                            GEO_TTL    EMP NAICS2012 county
# 1  Alamance County, North Carolina  50546        00    001
# 2  Alamance County, North Carolina     10        11    001
# 3  Alamance County, North Carolina      0        21    001
# 4    Bladen County, North Carolina  10408        00    017
# 5  Alamance County, North Carolina     97        22    001

# %% [markdown]
# ### Perform API calls
#
# * By county, collect data for all years

# %%
# Function: County data for all years
# returns a table of given county with total employees for 1986~2018
def county_all_years(county):
    census = []
    for year in np.arange(1986,2018):
        
        #print(year)
        
        cbp_url = f'https://api.census.gov/data/{year}/cbp?get='
        if (year >= 2017):
            variables = "NAICS2017,EMP"
        elif (year >= 2012):
            variables = "NAICS2012_TTL,EMP"
        elif (year > 2007):
            variables = "NAICS2007_TTL,EMP"
        elif (year > 2002):
            variables = "NAICS2002_TTL,EMP"
        elif (year > 1997):
            variables = "NAICS1997_TTL,EMP"
        else:
            variables = "GEO_TTL,EMP"
            
        url = cbp_url+variables+f'&for=county:{county}&in=state:37&key='+census_api_key
        if (year >= 2017):
            url = url + "&NAICS2017=00"
            
        #print(url)
        
        try:
            response = requests.get(url)
            #print(response)
            year_data = response.json()
            #print(json.dumps(year_data, indent=4))
            census.append(year_data[1][1])
        except:
            print(f"Found error")
        

    return census

# %% [markdown]
# * Running the following takes long time because of many api calls for the years.

# %%
emp_ct = county_all_years('183')
emp_ct_df = pd.DataFrame({
    "County" : ["183"]*len(emp_ct),
    "Year" : np.arange(1986,2018),
    "EMP" : emp_ct
})
emp_ct_df.head()
# Out:
#   County  Year     EMP
# 0    183  1986  171707
# 1    183  1987  180159
# 2    183  1988  188429
# 3    183  1989  199991
# 4    183  1990  214939

# %% [markdown]
# ### Exploring more about data for 2017~2018

# %%
url2017 = set_url(2017)

try:
    response = requests.get(url2017)
    print(response)
    census_data = response.json()
    #print(json.dumps(census_data, indent=4))
except:
    print(f"Found error")
    
df = pd.DataFrame(census_data, columns=census_data[0])
emp_df2017 = df.drop(0).drop("state",axis=1)
emp_df2017.head()
# Out:
# <Response [200]>
#                             NAME    EMP NAICS2017 county
# 1  Gaston County, North Carolina   1130        55    071
# 2  Gaston County, North Carolina   3071        42    071
# 3  Gaston County, North Carolina   3562        56    071
# 4  Gaston County, North Carolina   3150        81    071
# 5  Gaston County, North Carolina  64158        00    071

# %%
emp_df2017.loc[emp_df2017['NAICS2017']=='00']
# Out:
#                                   NAME    EMP NAICS2017 county
# 5        Gaston County, North Carolina  64158        00    071
# 27        Moore County, North Carolina  31029        00    125
# 37       Stanly County, North Carolina  16253        00    167
# 64       Yancey County, North Carolina   3382        00    199
# 74     McDowell County, North Carolina  13541        00    111
# ...                                ...    ...       ...    ...
# 1447  Cleveland County, North Carolina  30006        00    045
# 1467    Iredell County, North Carolina  67463        00    097
# 1486       Pitt County, North Carolina  60749        00    147
# 1499   Cherokee County, North Carolina   7487        00    039
# 1506     Wilkes County, North Carolina  19289        00    193
#
# [100 rows x 4 columns]

# %%
url ="https://api.census.gov/data/2018/cbp?get=NAICS2017_LABEL,NAICS2017,EMP&for=state:37&key="+census_api_key

# %%
try:
    response = requests.get(url)
    print(response)
    census_data = response.json()
    #print(json.dumps(census_data, indent=4))
except:
    print(f"Found error")
# Out:
# <Response [200]>

# %%
df = pd.DataFrame(census_data, columns=census_data[0])
emp_df2018=df.drop(0).drop("state",axis=1)
emp_df2018.head()
# Out:
#                                      NAICS2017_LABEL NAICS2017    EMP
# 1  Architectural and structural metals manufacturing      3323  11663
# 2                                            Logging    113310   2751
# 3                      Fishing, hunting and trapping       114     31
# 4  Electric power generation, transmission and di...      2211  18817
# 5                             Residential remodelers    236118   9078

# %%
emp_df2017
# Out:
#                                NAME    EMP NAICS2017 county
# 1     Gaston County, North Carolina   1130        55    071
# 2     Gaston County, North Carolina   3071        42    071
# 3     Gaston County, North Carolina   3562        56    071
# 4     Gaston County, North Carolina   3150        81    071
# 5     Gaston County, North Carolina  64158        00    071
# ...                             ...    ...       ...    ...
# 1511  Wilkes County, North Carolina    562        23    193
# 1512  Wilkes County, North Carolina     24        61    193
# 1513  Wilkes County, North Carolina   3166        62    193
# 1514  Wilkes County, North Carolina    430        42    193
# 1515  Wilkes County, North Carolina     62        71    193
#
# [1515 rows x 4 columns]

# %%
emp_df2018['EMP'].astype('int32').sum()
# Out:
# 23082493

# %%
emp_df2018.loc[emp_df2018['NAICS2017']=='00']
# Out:
#            NAICS2017_LABEL NAICS2017      EMP
# 277  Total for all sectors        00  3848565

# %%
def NC_census_for_2017_2018():    
    url_2018 = "https://api.census.gov/data/2018/cbp?get=NAICS2017,EMP&for=state:37&key="+census_api_key
    try:
        response = requests.get(url_2018)
        print(response)
        census2018 = response.json()
        #print(json.dumps(census_data, indent=4))
    except:
        print(f"Found error")
        
    url_2017 = "https://api.census.gov/data/2017/cbp?get=NAICS2017,EMP&for=state:37&key="+census_api_key
    try:
        response = requests.get(url_2018=7)
        print(response)
        census2017 = response.json()
        #print(json.dumps(census_data, indent=4))
    except:
        print(f"Found error")
    return census2017, census2018

# %% [markdown]
# ## State-wide API calls

# %%
## Set a url for given year to retrieve employee data for all counties.
def set_url_NC(year):
    
    cbp_url = f'https://api.census.gov/data/{year}/cbp?get='
    
    ## The quary variables vary in years
    if (year >= 2017):
        variables = "NAME,EMP"
    elif (year >= 2012):
        variables = "GEO_TTL,EMP"
    elif (year > 2007):
        variables = "NAICS2007_TTL,GEO_TTL,EMP"
    elif (year > 2002):
        variables = "NAICS2002_TTL,GEO_TTL,EMP"
    elif (year > 1997):
        variables = "NAICS1997_TTL,GEO_TTL,EMP"
    else:
        variables = "GEO_TTL,EMP"
    
    url = cbp_url+variables+"&for=state:37&key="+census_api_key
    
    # From 2012, there are subcategories upto 2~6 digits in NAICS codes. We collect only 2 digits codes.
    if (year >= 2012):
        url += set_naics_query(year)
    
    return url

# %%
urlNC = set_url_NC(2000)

try:
    response = requests.get(urlNC)
    print(response)
    census_data_NC = response.json()
    #print(json.dumps(census_data, indent=4))
except:
    print(f"Found error")
    
df_NC = pd.DataFrame(census_data_NC, columns=census_data_NC[0])
emp_df_NC = df_NC.drop(0).drop("state",axis=1)
emp_df_NC.head()
# Out:
# <Response [200]>
#   NAICS1997_TTL         GEO_TTL      EMP
# 1         Total  North Carolina  3385492

# %%
emp_df_NC['EMP'].astype('int32')
emp_df_NC.sort_values(by='EMP', ascending=False)
# Out:
#            GEO_TTL      EMP NAICS2012
# 14  North Carolina    94867        61
# 12  North Carolina    92537        55
# 8   North Carolina    80535        51
# 16  North Carolina    60055        71
# 15  North Carolina   560309        62
# 10  North Carolina    51023        53
# 2   North Carolina     4671        11
# 17  North Carolina   379757        72
# 1   North Carolina  3560448        00
# 13  North Carolina   355469        56
# 4   North Carolina     3233        21
# 11  North Carolina   203500        54
# 5   North Carolina    19494        22
# 7   North Carolina   174694        42
# 9   North Carolina   172319        52
# 6   North Carolina   167929        23
# 18  North Carolina   148355        81
# 3   North Carolina        0        99

# %% [markdown]
# ## Population Data
#
# ### NC 1990 Census table
#
# https://www.osbm.nc.gov/facts-figures/demographics/1990-2000-county-growth
#
# ### Census demographic api
#
# https://demography.osbm.nc.gov/explore/?sort=modified
#
# * state-wide population: https://demography.osbm.nc.gov/explore/dataset/historic-census/table/?disjunctive.areatype&disjunctive.areaname&rows=30&q.timerange.year=year:%5B1979-01-01T05:00:00Z+TO+2020-01-02T04:59:59Z%5D&refine.areatype=State
#
# * Downloaded historical NC census data for the cesus years : historic-census.json
#
# ### Census dot gov
# source(2000~2010) API : https://www.census.gov/data/developers/data-sets/popest-popproj/popest.2000-2010_Intercensals.html
#
# source(1990-2000) : Can't find county pop.
# https://www.census.gov/data/developers/data-sets/popest-popproj/popest.1990-2000_Intercensals.html
# do NOT have geographical variable.

# %%
# Histroic NC census data
query_years = ['1980', '1990', '2000']
years_pop = [
    ['year', 'county', 'population'],
    ['1990', 'STATE', '6628637'],
    ['1980', 'STATE', '5881766'],
    ['2000', 'STATE', '8046668']
]

with open("historic-census.json") as f:
    pop_data = json.load(f)
    #print(json.dumps(pop_data, indent=4))
    for each_data in pop_data:

        field_data = each_data['fields']
        #print(field_data['year'])
        if field_data['year'] in query_years:
            sel_data = [field_data['year'],
                       field_data['areaname'],
                       field_data['population']]
            years_pop.append(sel_data)
            #if field_data['areaname']=='Wake':
                #print(sel_data)

# %%
## API call for the population of counties in NC from 2000~2010
year = 2000
pop_url = f'https://api.census.gov/data/{year}/pep/int_population'
pop_var = '?get=GEONAME,POP,DATE_DESC&for=county:*&in=state:37'
apikey = '&key=' + census_api_key
print(pop_url+pop_var+apikey)
## Request
try:
    response = requests.get(pop_url+pop_var+apikey)
    print(response)
    pop_data = response.json()
    #print(json.dumps(census_data, indent=4))
except:
    print(f"Found error")
    
pop_df = pd.DataFrame(pop_data[1:], columns=pop_data[0])
#emp_df_NC = df_NC.drop(0).drop("state",axis=1)
pop_df.head()
# Out:
# https://api.census.gov/data/2000/pep/int_population?get=GEONAME,POP,DATE_DESC&for=county:*&in=state:37&key=c27d20165731bd731fe0b28ba84169ac2877e759
# <Response [200]>
#                          GEONAME    POP                     DATE_DESC state  \
# 0  Greene County, North Carolina  19848  7/1/2003 population estimate    37
# 1  Greene County, North Carolina  20132  7/1/2004 population estimate    37
# 2  Greene County, North Carolina  20146  7/1/2005 population estimate    37
# 3  Greene County, North Carolina  20742  7/1/2006 population estimate    37
# 4  Greene County, North Carolina  21178  7/1/2007 population estimate    37
#
#   county
# 0    079
# 1    079
# 2    079
# 3    079
# 4    079

# %%
years = []
counties = []
pop_array = []
for drow in pop_df.iterrows():
    row = drow[1]
    gname = row['GEONAME'].split()
    county = gname[0]
    counties.append(county)
    dt_str = row['DATE_DESC'].split()
    yr = dt_str[0].split('/')[2]
    years.append(yr)
    population = row['POP']
    pop_array.append(int(population))
    if int(yr) > 2000:
        years_pop.append([yr,county,population])
    
pop_df['YEAR'] = years
pop_df['CountyName'] = counties
pop_df['population'] = pop_array
pop_df.head()
# Out:
#                          GEONAME    POP                     DATE_DESC state  \
# 0  Greene County, North Carolina  19848  7/1/2003 population estimate    37
# 1  Greene County, North Carolina  20132  7/1/2004 population estimate    37
# 2  Greene County, North Carolina  20146  7/1/2005 population estimate    37
# 3  Greene County, North Carolina  20742  7/1/2006 population estimate    37
# 4  Greene County, North Carolina  21178  7/1/2007 population estimate    37
#
#   county  YEAR CountyName  population
# 0    079  2003     Greene       19848
# 1    079  2004     Greene       20132
# 2    079  2005     Greene       20146
# 3    079  2006     Greene       20742
# 4    079  2007     Greene       21178

# %%
pop_df.loc[pop_df['YEAR']=='2000'].head()
# Out:
#                             GEONAME     POP  \
# 8   Guilford County, North Carolina  420848
# 9   Guilford County, North Carolina  422324
# 20   Halifax County, North Carolina   57444
# 21   Halifax County, North Carolina   57306
# 32   Harnett County, North Carolina   90978
#
#                              DATE_DESC state county  YEAR CountyName  \
# 8   4/1/2000 population estimates base    37    081  2000   Guilford
# 9         7/1/2000 population estimate    37    081  2000   Guilford
# 20  4/1/2000 population estimates base    37    083  2000    Halifax
# 21        7/1/2000 population estimate    37    083  2000    Halifax
# 32  4/1/2000 population estimates base    37    085  2000    Harnett
#
#     population
# 8       420848
# 9       422324
# 20       57444
# 21       57306
# 32       90978

# %%
# Compute the total population for NC and append the data to years_pop array
pop_nums = pop_df.groupby(['YEAR'])['population'].sum()
for items in pop_nums.items():
    #print(items)
    if items[0]!='2000':
        years_pop.append([items[0], 'NC', items[1]])
print(years_pop)
# Out:
# [['year', 'county', 'population'], ['1990', 'STATE', '6628637'], ['1980', 'STATE', '5881766'], ['2000', 'STATE', '8046668'], ['1990', 'Beaufort', 42283.0], ['2000', 'Beaufort', 44958.0], ['1990', 'Burke', 75740.0], ['1980', 'Camden', 5829.0], ['2000', 'Camden', 6885.0], ['2000', 'Caswell', 23501.0], ['2000', 'Chatham', 49326.0], ['1980', 'Cherokee', 18933.0], ['2000', 'Chowan', 14150.0], ['1980', 'Clay', 6619.0], ['1990', 'Clay', 7155.0], ['2000', 'Clay', 8775.0], ['1990', 'Cleveland', 84713.0], ['1980', 'Dare', 13377.0], ['1990', 'Davidson', 126677.0], ['1990', 'Davie', 27859.0], ['1980', 'Edgecombe', 55988.0], ['1990', 'Forsyth', 265878.0], ['2000', 'Franklin', 47260.0], ['2000', 'Granville', 48498.0], ['1980', 'Harnett', 59570.0], ['1990', 'Jackson', 26846.0], ['1980', 'Lee', 36718.0], ['2000', 'Lee', 49170.0], ['1980', 'Lenoir', 59819.0], ['1990', 'Macon', 23499.0], ['2000', 'Macon', 29806.0], ['1990', 'Martin', 25078.0], ['2000', 'McDowell', 42151.0], ['2000', 'Mecklenburg', 695370.0], ['1990', 'Nash', 76677.0], ['2000', 'Alamance', 130800.0], ['1990', 'Alexander', 27544.0], ['2000', 'Pasquotank', 34897.0], ['1990', 'Anson', 23474.0], ['2000', 'Polk', 18324.0], ['2000', 'Brunswick', 73141.0], ['1990', 'Robeson', 105170.0], ['2000', 'Burke', 89145.0], ['2000', 'Caldwell', 77708.0], ['1990', 'Rowan', 110605.0], ['1980', 'Alamance', 99319.0], ['1990', 'Sampson', 47297.0], ['1980', 'Alleghany', 9587.0], ['1980', 'Stanly', 48517.0], ['1980', 'Catawba', 105208.0], ['2000', 'Catawba', 141686.0], ['1980', 'Union', 70436.0], ['1980', 'Vance', 36748.0], ['2000', 'Columbus', 54749.0], ['1980', 'Buncombe', 160897.0], ['1980', 'Cumberland', 247160.0], ['1980', 'Wilson', 63132.0], ['2000', 'Buncombe', 206310.0], ['1990', 'Cumberland', 274713.0], ['1990', 'Yadkin', 30488.0], ['1990', 'Currituck', 13736.0], ['1990', 'Yancey', 15419.0], ['1990', 'Cabarrus', 98935.0], ['1980', 'Davie', 24599.0], ['2000', 'Forsyth', 306063.0], ['1990', 'Chowan', 13506.0], ['2000', 'Gaston', 190336.0], ['1980', 'Graham', 7217.0], ['1980', 'Davidson', 113162.0], ['1990', 'Greene', 15384.0], ['1980', 'Haywood', 46495.0], ['2000', 'Duplin', 49063.0], ['1990', 'Hoke', 22856.0], ['2000', 'Hoke', 33650.0], ['1990', 'Gaston', 175093.0], ['1980', 'Gates', 8875.0], ['1990', 'Hyde', 5411.0], ['2000', 'Hyde', 5826.0], ['1990', 'Johnston', 81306.0], ['1980', 'Jones', 9705.0], ['1990', 'Halifax', 55516.0], ['2000', 'Lenoir', 59619.0], ['1990', 'Lincoln', 50319.0], ['2000', 'Harnett', 91085.0], ['2000', 'Haywood', 54033.0], ['1980', 'Alexander', 24999.0], ['2000', 'Henderson', 89193.0], ['2000', 'Alexander', 33603.0], ['1980', 'Hertford', 23368.0], ['1980', 'Anson', 25649.0], ['1980', 'Montgomery', 22469.0], ['2000', 'Ashe', 24384.0], ['1990', 'Northampton', 20798.0], ['1990', 'Lee', 41370.0], ['1980', 'Bladen', 30491.0], ['1990', 'Onslow', 149838.0], ['2000', 'Bladen', 32278.0], ['1980', 'Orange', 77055.0], ['1980', 'Cabarrus', 85895.0], ['1980', 'Pender', 22262.0], ['1980', 'McDowell', 35135.0], ['2000', 'Pender', 41082.0], ['1990', 'Caldwell', 70709.0], ['1980', 'Perquimans', 9486.0], ['1990', 'Camden', 5904.0], ['1980', 'Carteret', 41092.0], ['1980', 'Randolph', 91300.0], ['2000', 'Randolph', 130471.0], ['1990', 'Richmond', 44518.0], ['1990', 'Moore', 59000.0], ['1980', 'Nash', 67153.0], ['1990', 'Catawba', 118412.0], ['2000', 'Nash', 87385.0], ['1980', 'New Hanover', 103471.0], ['1980', 'Stokes', 33086.0], ['2000', 'Northampton', 22086.0], ['1980', 'Surry', 59449.0], ['1990', 'Swain', 11268.0], ['1980', 'Cleveland', 83435.0], ['2000', 'Onslow', 150355.0], ['1990', 'Ashe', 22209.0], ['1990', 'Transylvania', 25520.0], ['2000', 'Cleveland', 96258.0], ['2000', 'Orange', 115531.0], ['2000', 'Bertie', 19757.0], ['1990', 'Craven', 81613.0], ['2000', 'Craven', 91523.0], ['1980', 'Person', 29164.0], ['2000', 'Cumberland', 302960.0], ['1980', 'Currituck', 11089.0], ['2000', 'Person', 35623.0], ['1990', 'Buncombe', 174778.0], ['1980', 'Warren', 16232.0], ['1980', 'Burke', 72504 ...

# %%
with open("counties_pop_1990_2000.json", "w") as jfile:
    json.dump(years_pop, jfile)

# %%
cty = 'NC'
cyr = 2017
with open("counties_pop_1990_2000.json") as f:
    pop_data = json.load(f)
    print(pop_data[1])
    pp_data = pop_data[1:]
    #print(json.dumps(pop_data, indent=4))
    sel_pop = list(filter(lambda d: (d[1] == 'NC') & (int(d[0])<=cyr), pp_data))
print(sel_pop)
# Out:
# ['1990', 'NC', '6628637']
# [['1990', 'NC', '6628637'], ['1980', 'NC', '5881766'], ['2000', 'NC', '8046668'], ['2001', 'NC', 8210122], ['2002', 'NC', 8326201], ['2003', 'NC', 8422501], ['2004', 'NC', 8553152], ['2005', 'NC', 8705407], ['2006', 'NC', 8917270], ['2007', 'NC', 9118037], ['2008', 'NC', 9309449], ['2009', 'NC', 9449566], ['2010', 'NC', 9535483]]

# %%
# Out:
# ['Alamance', '151440', '151961', '152545', '153274', '155070', '156554', '159836', '163045', '166638', '170483']
# ['2010', 'Alamance', '151440']
# ['2011', 'Alamance', '151961']
# ['2012', 'Alamance', '152545']
# ['2013', 'Alamance', '153274']
# ['2014', 'Alamance', '155070']
# ['2015', 'Alamance', '156554']
# ['2016', 'Alamance', '159836']
# ['2017', 'Alamance', '163045']
# ['2018', 'Alamance', '166638']
# ['2019', 'Alamance', '170483']
# ['Alexander', '37235', '37158', '37323', '37414', '37597', '37550', '37908', '38070', '38303', '38530']
# ['2010', 'Alexander', '37235']
# ['2011', 'Alexander', '37158']
# ['2012', 'Alexander', '37323']
# ['2013', 'Alexander', '37414']
# ['2014', 'Alexander', '37597']
# ['2015', 'Alexander', '37550']
# ['2016', 'Alexander', '37908']
# ['2017', 'Alexander', '38070']
# ['2018', 'Alexander', '38303']
# ['2019', 'Alexander', '38530']
# ['Alleghany', '11139', '11068', '10993', '11065', '11180', '11237', '11297', '11378', '11422', '11466']
# ['2010', 'Alleghany', '11139']
# ['2011', 'Alleghany', '11068']
# ['2012', 'Alleghany', '10993']
# ['2013', 'Alleghany', '11065']
# ['2014', 'Alleghany', '11180']
# ['2015', 'Alleghany', '11237']
# ['2016', 'Alleghany', '11297']
# ['2017', 'Alleghany', '11378']
# ['2018', 'Alleghany', '11422']
# ['2019', 'Alleghany', '11466']
# ['Anson', '26852', '26699', '26597', '26288', '26304', '26035', '25644', '25490', '25288', '25290']
# ['2010', 'Anson', '26852']
# ['2011', 'Anson', '26699']
# ['2012', 'Anson', '26597']
# ['2013', 'Anson', '26288']
# ['2014', 'Anson', '26304']
# ['2015', 'Anson', '26035']
# ['2016', 'Anson', '25644']
# ['2017', 'Anson', '25490']
# ['2018', 'Anson', '25288']
# ['2019', 'Anson', '25290']
# ['Ashe', '27228', '27107', '27170', '27149', '27203', '26989', '27072', '27297', '27606', '27861']
# ['2010', 'Ashe', '27228']
# ['2011', 'Ashe', '27107']
# ['2012', 'Ashe', '27170']
# ['2013', 'Ashe', '27149']
# ['2014', 'Ashe', '27203']
# ['2015', 'Ashe', '26989']
# ['2016', 'Ashe', '27072']
# ['2017', 'Ashe', '27297']
# ['2018', 'Ashe', '27606']
# ['2019', 'Ashe', '27861']
# ['Avery', '17765', '17910', '17810', '17844', '17871', '17764', '17857', '17970', '18057', '18022']
# ['2010', 'Avery', '17765']
# ['2011', 'Avery', '17910']
# ['2012', 'Avery', '17810']
# ['2013', 'Avery', '17844']
# ['2014', 'Avery', '17871']
# ['2015', 'Avery', '17764']
# ['2016', 'Avery', '17857']
# ['2017', 'Avery', '17970']
# ['2018', 'Avery', '18057']
# ['2019', 'Avery', '18022']
# ['Beaufort', '47807', '47864', '47790', '47667', '47585', '47612', '47473', '47458', '47475', '47480']
# ['2010', 'Beaufort', '47807']
# ['2011', 'Beaufort', '47864']
# ['2012', 'Beaufort', '47790']
# ['2013', 'Beaufort', '47667']
# ['2014', 'Beaufort', '47585']
# ['2015', 'Beaufort', '47612']
# ['2016', 'Beaufort', '47473']
# ['2017', 'Beaufort', '47458']
# ['2018', 'Beaufort', '47475']
# ['2019', 'Beaufort', '47480']
# ['Bertie', '21245', '20937', '20574', '20463', '20454', '20409', '19798', '19780', '19709', '19636']
# ['2010', 'Bertie', '21245']
# ['2011', 'Bertie', '20937']
# ['2012', 'Bertie', '20574']
# ['2013', 'Bertie', '20463']
# ['2014', 'Bertie', '20454']
# ['2015', 'Bertie', '20409']
# ['2016', 'Bertie', '19798']
# ['2017', 'Bertie', '19780']
# ['2018', 'Bertie', '19709']
# ['2019', 'Bertie', '19636']
# ['Bladen', '35192', '35026', '35103', '35043', '35040', '34898', '34664', '34522', '34566', '34497']
# ['2010', 'Bladen', '35192']
# ['2011', 'Bladen', '35026']
# ['2012', 'Bladen', '35103']
# ['2013', 'Bladen', '35043']
# ['2014', 'Bladen', '35040']
# ['2015', 'Bladen', '34898']
# ['2016', 'Bladen', '34664']
# ['2017', 'Bladen', '34522']
# ['2018', 'Bladen', '34566']
# ['2019', 'Bladen', '34497']
# ['Brunswick', '108065', '110148', '112409', '115284', '119050', '122957', '127152', '131644', '137103', '142088']
# ['2010', 'Brunswick', '108065']
# ['2011', 'Brunswick', '110148']
# ['2012', 'Brunswick', '112409']
# ['2013', 'Brunswick', '115284']
# ['2014', 'Brunswick', '119050']
# ['2015', 'Brunswick', '122957']
# ['2016', 'Brunswick', '127152']
# ['2017', 'Brunswick', '131644']
# ['2018', 'Brunswick', '137103']
# ['2019', 'Brunswick', '142088']
# ['Buncombe', '238737', '241798', '244725', '247951', '250552', '253775', '257259', '259082', '261065', '264056']
# ['2010', 'Buncombe', '238737']
# ['2011', 'Buncombe', '241798']
# ['2012', 'Buncombe', '244725']
# ['2013', 'Buncombe', '247951']
# ['2014', 'Buncombe', '250552']
# ['2015', 'Buncombe', '253775']
# ['2016', 'Buncombe', '257259']
# ['2017', 'Buncombe', '259082']
# ['2018', 'Buncombe', '261065']
# ['2019', 'Buncombe', '264056']
# ['Burke', '90575', '90203', '89619', '89151', '89151', '89321', '90123', '91077', '91402', '91810']
# ['2010', 'Burke', '90575']
# ['2011', 'Burke', '90203']
# ['2012', 'Burke', '89619']
# ['2013', 'Burke', '89151']
# ['2014', 'Burke', '89151']
# ['2015', 'Burke', '89321']
# ['2016', 'Burke', '90123']
# ['2017', 'Burke', '91077']
# ['2018', 'Burke', '91402']
# ['2019', 'Burke', '91810']
# ['Cabarrus', '178535', '180684', '183253', '186067', '190218', '194982', '200230', '204865', '209150', '212917']
# ['2010', 'Cabarrus', '178535']
# ['2011', 'Cabarrus', '180684']
# ['2012', 'Cabarrus', '183253']
# ['2013', 'Cabarrus', '186067']
# ['2014', 'Cabarrus', '190218']
# ['2015', 'Cabarrus', '194982']
# ['2016', 'Cabarrus', '200230']
# ['2017', 'Cabarrus', '204865']
# ['2018', 'Cabarrus', '209150']
# ['2019', 'Cabarrus', '212917']
# ['Caldwell', '83021', '82937', '82695', '82605', '82598', '82765', '83143', '83227', '83291', '83417']
# ['2010', 'Caldwell', '83021']
# ['2011', 'Caldwell', '82937']
# ['2012', 'Caldwell', '82695']
# ['2013', 'Caldwell', '82605']
# ['2014', 'Caldwell', '82598']
# ['2015', 'Caldwell', '82765']
# ['2016', 'Caldwell', '83143']
# ['2017', 'Caldwell', '83227']
# ['2018', 'Caldwell', '83291']
# ['2019', 'Caldwell', '83417']
# ['Camden', '10009', '10035', '9966', '10075', '10210', '10214', '10290', '10352', '10490', '10611']
# ['2010', 'Camden', '10009']
# ['2011', 'Camden', '10035']
# ['2012', 'Camden', '9966']
# ['2013', 'Camden', '10075']
# ['2014', 'Camden', '10210']
# ['2015', 'Camden', '10214']
# ['2016', 'Camden', '10290']
# ['2017', 'Camden', '10352']
# ['2018', 'Camden', '10490']
# ['2019', 'Camden', '10611']
# ['Carteret', '66698', '67681', '68434', '69235', '69497', '69742', '69871', '70247', '70696', '71163']
# ['2010', 'Carteret', '66698']
# ['2011', 'Carteret', '67681']
# ['2012', 'Carteret', '68434']
# ['2013', 'Carteret', '69235']
# ['2014', 'Carteret', '69497']
# ['2015', 'Carteret', '69742']
# ['2016', 'Carteret', '69871']
# ['2017', 'Carteret', '70247']
# ['2018', 'Carteret', '70696']
# ['2019', 'Carteret', '71163']
# ['Caswell', '23753', '23723', '23487', '23688', '23482', '23491', '23527', '23480', '23679', '23664']
# ['2010', 'Caswell', '23753']
# ['2011', 'Caswell', '23723']
# ['2012', 'Caswell', '23487']
# ['2013', 'Caswell', '23688']
# ['2014', 'Caswell', '23482']
# ['2015', 'Caswell', '23491']
# ['2016', 'Caswell', '23527']
# ['2017', 'Caswell', '23480']
# ['2018', 'Caswell', '23679']
# ['2019', 'Caswell', '23664']
# ['Catawba', '154766', '155038', '155692', '155582', '155977', '156197', '156774', '157424', '158483', '159494']
# ['2010', 'Catawba', '154766']
# ['2011', 'Catawba', '155038']
# ['2012', 'Catawba', '155692']
# ['2013', 'Catawba', '155582']
# ['2014', 'Catawba', '155977']
# ['2015', 'Catawba', '156197']
# ['2016', 'Catawba', '156774']
# ['2017', 'Catawba', '157424']
# ['2018', 'Catawba', '158483']
# ['2019', 'Catawba', '159494']
# ['Chatham', '63840', '64396', '65152', '66117', '67373', '69228', '70746', '72570', '74264', '75994']
# ['2010', 'Chatham', '63840']
# ['2011', 'Chatham', '64396']
# ['2012', 'Chatham', '65152']
# ['2013', 'Chatham', '66117']
# ['2014', 'Chatham', '67373']
# ['2015', 'Chatham', '69228']
# ['2016', 'Chatham', '70746']
# ['2017', 'Chatham', '72570']
# ['2018', 'Chatham', '74264']
# ['2019', 'Chatham', '75994']
# ['Cherokee', '27431', '27468', '27414', '27443', '27517', '27729', '28544', '28879', '29275', '29630']
# ['2010', 'Cherokee', '27431']
# ['2011', 'Cherokee', '27468']
# ['2012', 'Cherokee', '27414']
# ['2013', 'Cherokee', '27443']
# ['2014', 'Cherokee', '27517']
# ['2015', 'Cherokee', '27729']
# ['2016', 'Cherokee', '28544']
# ['2017', 'Cherokee', '28879']
# ['2018', 'Cherokee', '29275']
# ['2019', 'Cherokee', '29630']
# ['Chowan', '14737', '14822', '14689', '14770', '14572', '14431', '14278', '14204', '14173', '14114']
# ['2010', 'Chowan', '14737']
# ['2011', 'Chowan', '14822']
# ['2012', 'Chowan', '14689']
# ['2013', 'Chowan', '14770']
# ['2014', 'Chowan', '14572']
# ['2015', 'Chowan', '14431']
# ['2016', 'Chowan', '14278']
# ['2017', 'Chowan', '14204']
# ['2018', 'Chowan', '14173']
# ['2019', 'Chowan', '14114']
# ['Clay', '10607', '10699', '10709', '10831', '10830', '10969', '11200', '11457', '11658', '11860']
# ['2010', 'Clay', '10607']
# ['2011', 'Clay', '10699']
# ['2012', 'Clay', '10709']
# ['2013', 'Clay', '10831']
# ['2014', 'Clay', '10830']
# ['2015', 'Clay', '10969']
# ['2016', 'Clay', '11200']
# ['2017', 'Clay', '11457']
# ['2018', 'Clay', '11658']
# ['2019', 'Clay', '11860']
# ['Cleveland', '97919', '97706', '97523', '97246', '97646', '97755', '98069', '98393', '99140', '99776']
# ['2010', 'Cleveland', '97919']
# ['2011', 'Cleveland', '97706']
# ['2012', 'Cleveland', '97523']
# ['2013', 'Cleveland', '97246']
# ['2014', 'Cleveland', '97646']
# ['2015', 'Cleveland', '97755']
# ['2016', 'Cleveland', '98069']
# ['2017', 'Cleveland', '98393']
# ['2018', 'Cleveland', '99140']
# ['2019', 'Cleveland', '99776']
# ['Columbus', '57975', '58019', '57989', '57726', '57504', '57188', '56842', '56699', '56424', '56290']
# ['2010', 'Columbus', '57975']
# ['2011', 'Columbus', '58019']
# ['2012', 'Columbus', '57989']
# ['2013', 'Columbus', '57726']
# ['2014', 'Columbus', '57504']
# ['2015', 'Columbus', '57188']
# ['2016', 'Columbus', '56842']
# ['2017', 'Columbus', '56699']
# ['2018', 'Columbus', '56424']
# ['2019', 'Columbus', '56290']
# ['Craven', '104176', '104523', '105170', '104213', '104069', '103111', '103184', '103426', '103594', '103779']
# ['2010', 'Craven', '104176']
# ['2011', 'Craven', '104523']
# ['2012', 'Craven', '105170']
# ['2013', 'Craven', '104213']
# ['2014', 'Craven', '104069']
# ['2015', 'Craven', '103111']
# ['2016', 'Craven', '103184']
# ['2017', 'Craven', '103426']
# ['2018', 'Craven', '103594']
# ['2019', 'Craven', '103779']
# ['Cumberland', '327195', '330874', '330007', '332224', '329360', '329046', '330048', '328529', '331764', '332455']
# ['2010', 'Cumberland', '327195']
# ['2011', 'Cumberland', '330874']
# ['2012', 'Cumberland', '330007']
# ['2013', 'Cumberland', '332224']
# ['2014', 'Cumberland', '329360']
# ['2015', 'Cumberland', '329046']
# ['2016', 'Cumberland', '330048']
# ['2017', 'Cumberland', '328529']
# ['2018', 'Cumberland', '331764']
# ['2019', 'Cumberland', '332455']
# ['Currituck', '23674', '23973', '24118', '24414', '24986', '25538', '26022', '26673', '27099', '27526']
# ['2010', 'Currituck', '23674']
# ['2011', 'Currituck', '23973']
# ['2012', 'Currituck', '24118']
# ['2013', 'Currituck', '24414']
# ['2014', 'Currituck', '24986']
# ['2015', 'Currituck', '25538']
# ['2016', 'Currituck', '26022']
# ['2017', 'Currituck', '26673']
# ['2018', 'Currituck', '27099']
# ['2019', 'Currituck', '27526']
# ['Dare', '33982', '34256', '34759', '35136', '35377', '35756', '36167', '36680', '36997', '37290']
# ['2010', 'Dare', '33982']
# ['2011', 'Dare', '34256']
# ['2012', 'Dare', '34759']
# ['2013', 'Dare', '35136']
# ['2014', 'Dare', '35377']
# ['2015', 'Dare', '35756']
# ['2016', 'Dare', '36167']
# ['2017', 'Dare', '36680']
# ['2018', 'Dare', '36997']
# ['2019', 'Dare', '37290']
# ['Davidson', '162861', '163044', '162994', '163498', '163869', '164418', '165613', '166591', '168093', '169468']
# ['2010', 'Davidson', '162861']
# ['2011', 'Davidson', '163044']
# ['2012', 'Davidson', '162994']
# ['2013', 'Davidson', '163498']
# ['2014', 'Davidson', '163869']
# ['2015', 'Davidson', '164418']
# ['2016', 'Davidson', '165613']
# ['2017', 'Davidson', '166591']
# ['2018', 'Davidson', '168093']
# ['2019', 'Davidson', '169468']
# ['Davie', '41255', '41276', '41276', '41403', '41345', '41625', '42142', '42635', '42976', '43430']
# ['2010', 'Davie', '41255']
# ['2011', 'Davie', '41276']
# ['2012', 'Davie', '41276']
# ['2013', 'Davie', '41403']
# ['2014', 'Davie', '41345']
# ['2015', 'Davie', '41625']
# ['2016', 'Davie', '42142']
# ['2017', 'Davie', '42635']
# ['2018', 'Davie', '42976']
# ['2019', 'Davie', '43430']
# ['Duplin', '58650', '59355', '59690', '59807', '59911', '59769', '59837', '59647', '59772', '59736']
# ['2010', 'Duplin', '58650']
# ['2011', 'Duplin', '59355']
# ['2012', 'Duplin', '59690']
# ['2013', 'Duplin', '59807']
# ['2014', 'Duplin', '59911']
# ['2015', 'Duplin', '59769']
# ['2016', 'Duplin', '59837']
# ['2017', 'Duplin', '59647']
# ['2018', 'Duplin', '59772']
# ['2019', 'Duplin', '59736']
# ['Durham', '271354', '275977', '281509', '286383', '292305', '296917', '302879', '306465', '311163', '315741']
# ['2010', 'Durham', '271354']
# ['2011', 'Durham', '275977']
# ['2012', 'Durham', '281509']
# ['2013', 'Durham', '286383']
# ['2014', 'Durham', '292305']
# ['2015', 'Durham', '296917']
# ['2016', 'Durham', '302879']
# ['2017', 'Durham', '306465']
# ['2018', 'Durham', '311163']
# ['2019', 'Durham', '315741']
# ['Edgecombe', '56626', '56213', '55975', '55545', '55332', '54268', '53458', '53159', '52724', '52586']
# ['2010', 'Edgecombe', '56626']
# ['2011', 'Edgecombe', '56213']
# ['2012', 'Edgecombe', '55975']
# ['2013', 'Edgecombe', '55545']
# ['2014', 'Edgecombe', '55332']
# ['2015', 'Edgecombe', '54268']
# ['2016', 'Edgecombe', '53458']
# ['2017', 'Edgecombe', '53159']
# ['2018', 'Edgecombe', '52724']
# ['2019', 'Edgecombe', '52586']
# ['Forsyth', '351393', '354384', '357490', '359892', '363212', '365378', '369029', '372845', '376309', '379693']
# ['2010', 'Forsyth', '351393']
# ['2011', 'Forsyth', '354384']
# ['2012', 'Forsyth', '357490']
# ['2013', 'Forsyth', '359892']
# ['2014', 'Forsyth', '363212']
# ['2015', 'Forsyth', '365378']
# ['2016', 'Forsyth', '369029']
# ['2017', 'Forsyth', '372845']
# ['2018', 'Forsyth', '376309']
# ['2019', 'Forsyth', '379693']
# ['Franklin', '60818', '60861', '61618', '62473', '63104', '64069', '65260', '66577', '68012', '69112']
# ['2010', 'Franklin', '60818']
# ['2011', 'Franklin', '60861']
# ['2012', 'Franklin', '61618']
# ['2013', 'Franklin', '62473']
# ['2014', 'Franklin', '63104']
# ['2015', 'Franklin', '64069']
# ['2016', 'Franklin', '65260']
# ['2017', 'Franklin', '66577']
# ['2018', 'Franklin', '68012']
# ['2019', 'Franklin', '69112']
# ['Gaston', '206105', '207339', '208317', '209364', '210195', '212197', '215269', '218445', '221006', '222744']
# ['2010', 'Gaston', '206105']
# ['2011', 'Gaston', '207339']
# ['2012', 'Gaston', '208317']
# ['2013', 'Gaston', '209364']
# ['2014', 'Gaston', '210195']
# ['2015', 'Gaston', '212197']
# ['2016', 'Gaston', '215269']
# ['2017', 'Gaston', '218445']
# ['2018', 'Gaston', '221006']
# ['2019', 'Gaston', '222744']
# ['Gates', '12165', '12045', '12104', '11882', '11943', '11819', '11984', '12021', '12094', '12132']
# ['2010', 'Gates', '12165']
# ['2011', 'Gates', '12045']
# ['2012', 'Gates', '12104']
# ['2013', 'Gates', '11882']
# ['2014', 'Gates', '11943']
# ['2015', 'Gates', '11819']
# ['2016', 'Gates', '11984']
# ['2017', 'Gates', '12021']
# ['2018', 'Gates', '12094']
# ['2019', 'Gates', '12132']
# ['Graham', '8870', '8858', '8862', '8860', '8820', '8751', '8830', '8752', '8686', '8687']
# ['2010', 'Graham', '8870']
# ['2011', 'Graham', '8858']
# ['2012', 'Graham', '8862']
# ['2013', 'Graham', '8860']
# ['2014', 'Graham', '8820']
# ['2015', 'Graham', '8751']
# ['2016', 'Graham', '8830']
# ['2017', 'Graham', '8752']
# ['2018', 'Graham', '8686']
# ['2019', 'Graham', '8687']
# ['Granville', '57665', '57730', '57686', '57564', '57819', '58226', '59048', '60112', '60700', '61406']
# ['2010', 'Granville', '57665']
# ['2011', 'Granville', '57730']
# ['2012', 'Granville', '57686']
# ['2013', 'Granville', '57564']
# ['2014', 'Granville', '57819']
# ['2015', 'Granville', '58226']
# ['2016', 'Granville', '59048']
# ['2017', 'Granville', '60112']
# ['2018', 'Granville', '60700']
# ['2019', 'Granville', '61406']
# ['Greene', '21259', '21515', '21239', '20960', '21101', '21016', '21274', '21305', '21024', '21050']
# ['2010', 'Greene', '21259']
# ['2011', 'Greene', '21515']
# ['2012', 'Greene', '21239']
# ['2013', 'Greene', '20960']
# ['2014', 'Greene', '21101']
# ['2015', 'Greene', '21016']
# ['2016', 'Greene', '21274']
# ['2017', 'Greene', '21305']
# ['2018', 'Greene', '21024']
# ['2019', 'Greene', '21050']
# ['Guilford', '489589', '495082', '501431', '507000', '511636', '516493', '523934', '528041', '534346', '539666']
# ['2010', 'Guilford', '489589']
# ['2011', 'Guilford', '495082']
# ['2012', 'Guilford', '501431']
# ['2013', 'Guilford', '507000']
# ['2014', 'Guilford', '511636']
# ['2015', 'Guilford', '516493']
# ['2016', 'Guilford', '523934']
# ['2017', 'Guilford', '528041']
# ['2018', 'Guilford', '534346']
# ['2019', 'Guilford', '539666']
# ['Halifax', '54474', '54257', '53977', '53447', '52905', '52212', '52116', '51973', '51552', '51194']
# ['2010', 'Halifax', '54474']
# ['2011', 'Halifax', '54257']
# ['2012', 'Halifax', '53977']
# ['2013', 'Halifax', '53447']
# ['2014', 'Halifax', '52905']
# ['2015', 'Halifax', '52212']
# ['2016', 'Halifax', '52116']
# ['2017', 'Halifax', '51973']
# ['2018', 'Halifax', '51552']
# ['2019', 'Halifax', '51194']
# ['Harnett', '115742', '118597', '121317', '123428', '125600', '127038', '129434', '131042', '133172', '135239']
# ['2010', 'Harnett', '115742']
# ['2011', 'Harnett', '118597']
# ['2012', 'Harnett', '121317']
# ['2013', 'Harnett', '123428']
# ['2014', 'Harnett', '125600']
# ['2015', 'Harnett', '127038']
# ['2016', 'Harnett', '129434']
# ['2017', 'Harnett', '131042']
# ['2018', 'Harnett', '133172']
# ['2019', 'Harnett', '135239']
# ['Haywood', '58935', '59165', '59150', '59545', '59810', '60451', '61534', '62488', '62839', '63328']
# ['2010', 'Haywood', '58935']
# ['2011', 'Haywood', '59165']
# ['2012', 'Haywood', '59150']
# ['2013', 'Haywood', '59545']
# ['2014', 'Haywood', '59810']
# ['2015', 'Haywood', '60451']
# ['2016', 'Haywood', '61534']
# ['2017', 'Haywood', '62488']
# ['2018', 'Haywood', '62839']
# ['2019', 'Haywood', '63328']
# ['Henderson', '106887', '107244', '107740', '108752', '110485', '111854', '113889', '115384', '116857', '118312']
# ['2010', 'Henderson', '106887']
# ['2011', 'Henderson', '107244']
# ['2012', 'Henderson', '107740']
# ['2013', 'Henderson', '108752']
# ['2014', 'Henderson', '110485']
# ['2015', 'Henderson', '111854']
# ['2016', 'Henderson', '113889']
# ['2017', 'Henderson', '115384']
# ['2018', 'Henderson', '116857']
# ['2019', 'Henderson', '118312']
# ['Hertford', '24763', '24743', '24548', '24623', '24591', '24508', '24238', '24054', '24093', '24037']
# ['2010', 'Hertford', '24763']
# ['2011', 'Hertford', '24743']
# ['2012', 'Hertford', '24548']
# ['2013', 'Hertford', '24623']
# ['2014', 'Hertford', '24591']
# ['2015', 'Hertford', '24508']
# ['2016', 'Hertford', '24238']
# ['2017', 'Hertford', '24054']
# ['2018', 'Hertford', '24093']
# ['2019', 'Hertford', '24037']
# ['Hoke', '47496', '49142', '50000', '50581', '50813', '51735', '52138', '53331', '53992', '54842']
# ['2010', 'Hoke', '47496']
# ['2011', 'Hoke', '49142']
# ['2012', 'Hoke', '50000']
# ['2013', 'Hoke', '50581']
# ['2014', 'Hoke', '50813']
# ['2015', 'Hoke', '51735']
# ['2016', 'Hoke', '52138']
# ['2017', 'Hoke', '53331']
# ['2018', 'Hoke', '53992']
# ['2019', 'Hoke', '54842']
# ['Hyde', '5811', '5799', '5708', '5745', '5670', '5571', '5570', '5442', '5198', '5181']
# ['2010', 'Hyde', '5811']
# ['2011', 'Hyde', '5799']
# ['2012', 'Hyde', '5708']
# ['2013', 'Hyde', '5745']
# ['2014', 'Hyde', '5670']
# ['2015', 'Hyde', '5571']
# ['2016', 'Hyde', '5570']
# ['2017', 'Hyde', '5442']
# ['2018', 'Hyde', '5198']
# ['2019', 'Hyde', '5181']
# ['Iredell', '159768', '160988', '162819', '164834', '166862', '169776', '173088', '176089', '178730', '181380']
# ['2010', 'Iredell', '159768']
# ['2011', 'Iredell', '160988']
# ['2012', 'Iredell', '162819']
# ['2013', 'Iredell', '164834']
# ['2014', 'Iredell', '166862']
# ['2015', 'Iredell', '169776']
# ['2016', 'Iredell', '173088']
# ['2017', 'Iredell', '176089']
# ['2018', 'Iredell', '178730']
# ['2019', 'Iredell', '181380']
# ['Jackson', '40357', '40383', '40706', '40826', '41131', '41590', '43003', '43544', '43819', '44335']
# ['2010', 'Jackson', '40357']
# ['2011', 'Jackson', '40383']
# ['2012', 'Jackson', '40706']
# ['2013', 'Jackson', '40826']
# ['2014', 'Jackson', '41131']
# ['2015', 'Jackson', '41590']
# ['2016', 'Jackson', '43003']
# ['2017', 'Jackson', '43544']
# ['2018', 'Jackson', '43819']
# ['2019', 'Jackson', '44335']
# ['Johnston', '169681', '172109', '174207', '176620', '179734', '183619', '188749', '193902', '199790', '205951']
# ['2010', 'Johnston', '169681']
# ['2011', 'Johnston', '172109']
# ['2012', 'Johnston', '174207']
# ['2013', 'Johnston', '176620']
# ['2014', 'Johnston', '179734']
# ['2015', 'Johnston', '183619']
# ['2016', 'Johnston', '188749']
# ['2017', 'Johnston', '193902']
# ['2018', 'Johnston', '199790']
# ['2019', 'Johnston', '205951']
# ['Jones', '10143', '10330', '10410', '10355', '10245', '10205', '10123', '10123', '10196', '10196']
# ['2010', 'Jones', '10143']
# ['2011', 'Jones', '10330']
# ['2012', 'Jones', '10410']
# ['2013', 'Jones', '10355']
# ['2014', 'Jones', '10245']
# ['2015', 'Jones', '10205']
# ['2016', 'Jones', '10123']
# ['2017', 'Jones', '10123']
# ['2018', 'Jones', '10196']
# ['2019', 'Jones', '10196']
# ['Lee', '57886', '58294', '58820', '59028', '58930', '58711', '59181', '59810', '60878', '61690']
# ['2010', 'Lee', '57886']
# ['2011', 'Lee', '58294']
# ['2012', 'Lee', '58820']
# ['2013', 'Lee', '59028']
# ['2014', 'Lee', '58930']
# ['2015', 'Lee', '58711']
# ['2016', 'Lee', '59181']
# ['2017', 'Lee', '59810']
# ['2018', 'Lee', '60878']
# ['2019', 'Lee', '61690']
# ['Lenoir', '59492', '59563', '59280', '58853', '58557', '58225', '57653', '57175', '56856', '56372']
# ['2010', 'Lenoir', '59492']
# ['2011', 'Lenoir', '59563']
# ['2012', 'Lenoir', '59280']
# ['2013', 'Lenoir', '58853']
# ['2014', 'Lenoir', '58557']
# ['2015', 'Lenoir', '58225']
# ['2016', 'Lenoir', '57653']
# ['2017', 'Lenoir', '57175']
# ['2018', 'Lenoir', '56856']
# ['2019', 'Lenoir', '56372']
# ['Lincoln', '78104', '78321', '78757', '79217', '79892', '80936', '81884', '83052', '84751', '86453']
# ['2010', 'Lincoln', '78104']
# ['2011', 'Lincoln', '78321']
# ['2012', 'Lincoln', '78757']
# ['2013', 'Lincoln', '79217']
# ['2014', 'Lincoln', '79892']
# ['2015', 'Lincoln', '80936']
# ['2016', 'Lincoln', '81884']
# ['2017', 'Lincoln', '83052']
# ['2018', 'Lincoln', '84751']
# ['2019', 'Lincoln', '86453']
# ['Macon', '33958', '33969', '34050', '34184', '34529', '34803', '35117', '35614', '36101', '36498']
# ['2010', 'Macon', '33958']
# ['2011', 'Macon', '33969']
# ['2012', 'Macon', '34050']
# ['2013', 'Macon', '34184']
# ['2014', 'Macon', '34529']
# ['2015', 'Macon', '34803']
# ['2016', 'Macon', '35117']
# ['2017', 'Macon', '35614']
# ['2018', 'Macon', '36101']
# ['2019', 'Macon', '36498']
# ['Madison', '20779', '20916', '21216', '21415', '21619', '21739', '22039', '22215', '22361', '22602']
# ['2010', 'Madison', '20779']
# ['2011', 'Madison', '20916']
# ['2012', 'Madison', '21216']
# ['2013', 'Madison', '21415']
# ['2014', 'Madison', '21619']
# ['2015', 'Madison', '21739']
# ['2016', 'Madison', '22039']
# ['2017', 'Madison', '22215']
# ['2018', 'Madison', '22361']
# ['2019', 'Madison', '22602']
# ['Martin', '24501', '24101', '23806', '23583', '23565', '23544', '23453', '23303', '23264', '23150']
# ['2010', 'Martin', '24501']
# ['2011', 'Martin', '24101']
# ['2012', 'Martin', '23806']
# ['2013', 'Martin', '23583']
# ['2014', 'Martin', '23565']
# ['2015', 'Martin', '23544']
# ['2016', 'Martin', '23453']
# ['2017', 'Martin', '23303']
# ['2018', 'Martin', '23264']
# ['2019', 'Martin', '23150']
# ['McDowell', '45098', '45139', '45267', '45284', '45329', '45447', '45531', '46099', '46373', '46684']
# ['2010', 'McDowell', '45098']
# ['2011', 'McDowell', '45139']
# ['2012', 'McDowell', '45267']
# ['2013', 'McDowell', '45284']
# ['2014', 'McDowell', '45329']
# ['2015', 'McDowell', '45447']
# ['2016', 'McDowell', '45531']
# ['2017', 'McDowell', '46099']
# ['2018', 'McDowell', '46373']
# ['2019', 'McDowell', '46684']
# ['Mecklenburg', '923258', '940887', '961255', '990504', '1010400', '1033682', '1054613', '1073159', '1088350', '1108107']
# ['2010', 'Mecklenburg', '923258']
# ['2011', 'Mecklenburg', '940887']
# ['2012', 'Mecklenburg', '961255']
# ['2013', 'Mecklenburg', '990504']
# ['2014', 'Mecklenburg', '1010400']
# ['2015', 'Mecklenburg', '1033682']
# ['2016', 'Mecklenburg', '1054613']
# ['2017', 'Mecklenburg', '1073159']
# ['2018', 'Mecklenburg', '1088350']
# ['2019', 'Mecklenburg', '1108107']
# ['Mitchell', '15507', '15335', '15349', '15328', '15258', '15187', '15145', '15167', '15223', '15239']
# ['2010', 'Mitchell', '15507']
# ['2011', 'Mitchell', '15335']
# ['2012', 'Mitchell', '15349']
# ['2013', 'Mitchell', '15328']
# ['2014', 'Mitchell', '15258']
# ['2015', 'Mitchell', '15187']
# ['2016', 'Mitchell', '15145']
# ['2017', 'Mitchell', '15167']
# ['2018', 'Mitchell', '15223']
# ['2019', 'Mitchell', '15239']
# ['Montgomery', '27731', '27826', '27796', '27702', '27668', '27744', '27702', '27733', '27621', '27666']
# ['2010', 'Montgomery', '27731']
# ['2011', 'Montgomery', '27826']
# ['2012', 'Montgomery', '27796']
# ['2013', 'Montgomery', '27702']
# ['2014', 'Montgomery', '27668']
# ['2015', 'Montgomery', '27744']
# ['2016', 'Montgomery', '27702']
# ['2017', 'Montgomery', '27733']
# ['2018', 'Montgomery', '27621']
# ['2019', 'Montgomery', '27666']
# ['Moore', '88587', '89291', '90560', '91721', '92903', '94159', '95812', '97625', '99390', '101180']
# ['2010', 'Moore', '88587']
# ['2011', 'Moore', '89291']
# ['2012', 'Moore', '90560']
# ['2013', 'Moore', '91721']
# ['2014', 'Moore', '92903']
# ['2015', 'Moore', '94159']
# ['2016', 'Moore', '95812']
# ['2017', 'Moore', '97625']
# ['2018', 'Moore', '99390']
# ['2019', 'Moore', '101180']
# ['Nash', '95789', '95763', '95212', '94504', '94320', '94162', '94302', '94910', '95327', '95647']
# ['2010', 'Nash', '95789']
# ['2011', 'Nash', '95763']
# ['2012', 'Nash', '95212']
# ['2013', 'Nash', '94504']
# ['2014', 'Nash', '94320']
# ['2015', 'Nash', '94162']
# ['2016', 'Nash', '94302']
# ['2017', 'Nash', '94910']
# ['2018', 'Nash', '95327']
# ['2019', 'Nash', '95647']
# ['New Hanover', '203286', '206299', '209734', '213466', '216910', '219602', '225070', '229118', '232248', '235560']
# ['2010', 'New Hanover', '203286']
# ['2011', 'New Hanover', '206299']
# ['2012', 'New Hanover', '209734']
# ['2013', 'New Hanover', '213466']
# ['2014', 'New Hanover', '216910']
# ['2015', 'New Hanover', '219602']
# ['2016', 'New Hanover', '225070']
# ['2017', 'New Hanover', '229118']
# ['2018', 'New Hanover', '232248']
# ['2019', 'New Hanover', '235560']
# ['Northampton', '22039', '21900', '21502', '21267', '21201', '21143', '20895', '20908', '20618', '20527']
# ['2010', 'Northampton', '22039']
# ['2011', 'Northampton', '21900']
# ['2012', 'Northampton', '21502']
# ['2013', 'Northampton', '21267']
# ['2014', 'Northampton', '21201']
# ['2015', 'Northampton', '21143']
# ['2016', 'Northampton', '20895']
# ['2017', 'Northampton', '20908']
# ['2018', 'Northampton', '20618']
# ['2019', 'Northampton', '20527']
# ['Onslow', '186889', '186457', '191183', '193505', '192684', '193966', '193505', '196535', '198740', '201548']
# ['2010', 'Onslow', '186889']
# ['2011', 'Onslow', '186457']
# ['2012', 'Onslow', '191183']
# ['2013', 'Onslow', '193505']
# ['2014', 'Onslow', '192684']
# ['2015', 'Onslow', '193966']
# ['2016', 'Onslow', '193505']
# ['2017', 'Onslow', '196535']
# ['2018', 'Onslow', '198740']
# ['2019', 'Onslow', '201548']
# ['Orange', '133986', '135287', '138300', '139427', '140103', '140678', '142148', '142597', '145574', '147093']
# ['2010', 'Orange', '133986']
# ['2011', 'Orange', '135287']
# ['2012', 'Orange', '138300']
# ['2013', 'Orange', '139427']
# ['2014', 'Orange', '140103']
# ['2015', 'Orange', '140678']
# ['2016', 'Orange', '142148']
# ['2017', 'Orange', '142597']
# ['2018', 'Orange', '145574']
# ['2019', 'Orange', '147093']
# ['Pamlico', '13110', '13221', '13138', '13009', '13118', '13122', '13278', '13245', '13359', '13266']
# ['2010', 'Pamlico', '13110']
# ['2011', 'Pamlico', '13221']
# ['2012', 'Pamlico', '13138']
# ['2013', 'Pamlico', '13009']
# ['2014', 'Pamlico', '13118']
# ['2015', 'Pamlico', '13122']
# ['2016', 'Pamlico', '13278']
# ['2017', 'Pamlico', '13245']
# ['2018', 'Pamlico', '13359']
# ['2019', 'Pamlico', '13266']
# ['Pasquotank', '40629', '40131', '40018', '39257', '39459', '39554', '39894', '39780', '39790', '39731']
# ['2010', 'Pasquotank', '40629']
# ['2011', 'Pasquotank', '40131']
# ['2012', 'Pasquotank', '40018']
# ['2013', 'Pasquotank', '39257']
# ['2014', 'Pasquotank', '39459']
# ['2015', 'Pasquotank', '39554']
# ['2016', 'Pasquotank', '39894']
# ['2017', 'Pasquotank', '39780']
# ['2018', 'Pasquotank', '39790']
# ['2019', 'Pasquotank', '39731']
# ['Pender', '52416', '53328', '54070', '55194', '56320', '57761', '59258', '60771', '62168', '63406']
# ['2010', 'Pender', '52416']
# ['2011', 'Pender', '53328']
# ['2012', 'Pender', '54070']
# ['2013', 'Pender', '55194']
# ['2014', 'Pender', '56320']
# ['2015', 'Pender', '57761']
# ['2016', 'Pender', '59258']
# ['2017', 'Pender', '60771']
# ['2018', 'Pender', '62168']
# ['2019', 'Pender', '63406']
# ['Perquimans', '13481', '13588', '13733', '13811', '13720', '13701', '13654', '13678', '13652', '13639']
# ['2010', 'Perquimans', '13481']
# ['2011', 'Perquimans', '13588']
# ['2012', 'Perquimans', '13733']
# ['2013', 'Perquimans', '13811']
# ['2014', 'Perquimans', '13720']
# ['2015', 'Perquimans', '13701']
# ['2016', 'Perquimans', '13654']
# ['2017', 'Perquimans', '13678']
# ['2018', 'Perquimans', '13652']
# ['2019', 'Perquimans', '13639']
# ['Person', '39413', '39460', '39115', '39138', '39247', '39538', '39753', '39882', '40208', '40370']
# ['2010', 'Person', '39413']
# ['2011', 'Person', '39460']
# ['2012', 'Person', '39115']
# ['2013', 'Person', '39138']
# ['2014', 'Person', '39247']
# ['2015', 'Person', '39538']
# ['2016', 'Person', '39753']
# ['2017', 'Person', '39882']
# ['2018', 'Person', '40208']
# ['2019', 'Person', '40370']
# ['Pitt', '168853', '170298', '172509', '173875', '174211', '175475', '176060', '177705', '178440', '179731']
# ['2010', 'Pitt', '168853']
# ['2011', 'Pitt', '170298']
# ['2012', 'Pitt', '172509']
# ['2013', 'Pitt', '173875']
# ['2014', 'Pitt', '174211']
# ['2015', 'Pitt', '175475']
# ['2016', 'Pitt', '176060']
# ['2017', 'Pitt', '177705']
# ['2018', 'Pitt', '178440']
# ['2019', 'Pitt', '179731']
# ['Polk', '20481', '20358', '20309', '20589', '20818', '20896', '21127', '21303', '21535', '21696']
# ['2010', 'Polk', '20481']
# ['2011', 'Polk', '20358']
# ['2012', 'Polk', '20309']
# ['2013', 'Polk', '20589']
# ['2014', 'Polk', '20818']
# ['2015', 'Polk', '20896']
# ['2016', 'Polk', '21127']
# ['2017', 'Polk', '21303']
# ['2018', 'Polk', '21535']
# ['2019', 'Polk', '21696']
# ['Randolph', '141986', '141929', '142419', '142398', '142749', '142816', '143444', '143620', '144085', '144914']
# ['2010', 'Randolph', '141986']
# ['2011', 'Randolph', '141929']
# ['2012', 'Randolph', '142419']
# ['2013', 'Randolph', '142398']
# ['2014', 'Randolph', '142749']
# ['2015', 'Randolph', '142816']
# ['2016', 'Randolph', '143444']
# ['2017', 'Randolph', '143620']
# ['2018', 'Randolph', '144085']
# ['2019', 'Randolph', '144914']
# ['Richmond', '46633', '46610', '46146', '45924', '45439', '45353', '44957', '45155', '45199', '45079']
# ['2010', 'Richmond', '46633']
# ['2011', 'Richmond', '46610']
# ['2012', 'Richmond', '46146']
# ['2013', 'Richmond', '45924']
# ['2014', 'Richmond', '45439']
# ['2015', 'Richmond', '45353']
# ['2016', 'Richmond', '44957']
# ['2017', 'Richmond', '45155']
# ['2018', 'Richmond', '45199']
# ['2019', 'Richmond', '45079']
# ['Robeson', '134496', '134578', '134399', '134138', '133659', '133493', '132787', '132041', '131600', '131056']
# ['2010', 'Robeson', '134496']
# ['2011', 'Robeson', '134578']
# ['2012', 'Robeson', '134399']
# ['2013', 'Robeson', '134138']
# ['2014', 'Robeson', '133659']
# ['2015', 'Robeson', '133493']
# ['2016', 'Robeson', '132787']
# ['2017', 'Robeson', '132041']
# ['2018', 'Robeson', '131600']
# ['2019', 'Robeson', '131056']
# ['Rockingham', '93658', '93276', '92800', '92210', '92441', '92055', '91936', '91447', '91746', '91788']
# ['2010', 'Rockingham', '93658']
# ['2011', 'Rockingham', '93276']
# ['2012', 'Rockingham', '92800']
# ['2013', 'Rockingham', '92210']
# ['2014', 'Rockingham', '92441']
# ['2015', 'Rockingham', '92055']
# ['2016', 'Rockingham', '91936']
# ['2017', 'Rockingham', '91447']
# ['2018', 'Rockingham', '91746']
# ['2019', 'Rockingham', '91788']
# ['Rowan', '138368', '137841', '137765', '138118', '138897', '139639', '140557', '141445', '141802', '142643']
# ['2010', 'Rowan', '138368']
# ['2011', 'Rowan', '137841']
# ['2012', 'Rowan', '137765']
# ['2013', 'Rowan', '138118']
# ['2014', 'Rowan', '138897']
# ['2015', 'Rowan', '139639']
# ['2016', 'Rowan', '140557']
# ['2017', 'Rowan', '141445']
# ['2018', 'Rowan', '141802']
# ['2019', 'Rowan', '142643']
# ['Rutherford', '67737', '67928', '67920', '67705', '67545', '67627', '67679', '68279', '68423', '68908']
# ['2010', 'Rutherford', '67737']
# ['2011', 'Rutherford', '67928']
# ['2012', 'Rutherford', '67920']
# ['2013', 'Rutherford', '67705']
# ['2014', 'Rutherford', '67545']
# ['2015', 'Rutherford', '67627']
# ['2016', 'Rutherford', '67679']
# ['2017', 'Rutherford', '68279']
# ['2018', 'Rutherford', '68423']
# ['2019', 'Rutherford', '68908']
# ['Sampson', '63536', '63694', '63967', '64152', '64160', '63900', '63661', '63872', '64087', '64284']
# ['2010', 'Sampson', '63536']
# ['2011', 'Sampson', '63694']
# ['2012', 'Sampson', '63967']
# ['2013', 'Sampson', '64152']
# ['2014', 'Sampson', '64160']
# ['2015', 'Sampson', '63900']
# ['2016', 'Sampson', '63661']
# ['2017', 'Sampson', '63872']
# ['2018', 'Sampson', '64087']
# ['2019', 'Sampson', '64284']
# ['Scotland', '36063', '36401', '36262', '36079', '35971', '35718', '35842', '35843', '35744', '35732']
# ['2010', 'Scotland', '36063']
# ['2011', 'Scotland', '36401']
# ['2012', 'Scotland', '36262']
# ['2013', 'Scotland', '36079']
# ['2014', 'Scotland', '35971']
# ['2015', 'Scotland', '35718']
# ['2016', 'Scotland', '35842']
# ['2017', 'Scotland', '35843']
# ['2018', 'Scotland', '35744']
# ['2019', 'Scotland', '35732']
# ['Stanly', '60576', '60605', '60363', '60586', '61026', '61212', '61696', '62736', '63328', '63727']
# ['2010', 'Stanly', '60576']
# ['2011', 'Stanly', '60605']
# ['2012', 'Stanly', '60363']
# ['2013', 'Stanly', '60586']
# ['2014', 'Stanly', '61026']
# ['2015', 'Stanly', '61212']
# ['2016', 'Stanly', '61696']
# ['2017', 'Stanly', '62736']
# ['2018', 'Stanly', '63328']
# ['2019', 'Stanly', '63727']
# ['Stokes', '47349', '47234', '46995', '46648', '46723', '46557', '46581', '46617', '46472', '46420']
# ['2010', 'Stokes', '47349']
# ['2011', 'Stokes', '47234']
# ['2012', 'Stokes', '46995']
# ['2013', 'Stokes', '46648']
# ['2014', 'Stokes', '46723']
# ['2015', 'Stokes', '46557']
# ['2016', 'Stokes', '46581']
# ['2017', 'Stokes', '46617']
# ['2018', 'Stokes', '46472']
# ['2019', 'Stokes', '46420']
# ['Surry', '73769', '73536', '73472', '73014', '73432', '72535', '72732', '73047', '73232', '73232']
# ['2010', 'Surry', '73769']
# ['2011', 'Surry', '73536']
# ['2012', 'Surry', '73472']
# ['2013', 'Surry', '73014']
# ['2014', 'Surry', '73432']
# ['2015', 'Surry', '72535']
# ['2016', 'Surry', '72732']
# ['2017', 'Surry', '73047']
# ['2018', 'Surry', '73232']
# ['2019', 'Surry', '73232']
# ['Swain', '14011', '14188', '14423', '14538', '14785', '14867', '14729', '14713', '14442', '14275']
# ['2010', 'Swain', '14011']
# ['2011', 'Swain', '14188']
# ['2012', 'Swain', '14423']
# ['2013', 'Swain', '14538']
# ['2014', 'Swain', '14785']
# ['2015', 'Swain', '14867']
# ['2016', 'Swain', '14729']
# ['2017', 'Swain', '14713']
# ['2018', 'Swain', '14442']
# ['2019', 'Swain', '14275']
# ['Transylvania', '33087', '33007', '33020', '33153', '33400', '33725', '34074', '34495', '35115', '35484']
# ['2010', 'Transylvania', '33087']
# ['2011', 'Transylvania', '33007']
# ['2012', 'Transylvania', '33020']
# ['2013', 'Transylvania', '33153']
# ['2014', 'Transylvania', '33400']
# ['2015', 'Transylvania', '33725']
# ['2016', 'Transylvania', '34074']
# ['2017', 'Transylvania', '34495']
# ['2018', 'Transylvania', '35115']
# ['2019', 'Transylvania', '35484']
# ['Tyrrell', '4415', '4350', '4135', '4138', '4144', '4219', '4133', '4304', '4260', '4259']
# ['2010', 'Tyrrell', '4415']
# ['2011', 'Tyrrell', '4350']
# ['2012', 'Tyrrell', '4135']
# ['2013', 'Tyrrell', '4138']
# ['2014', 'Tyrrell', '4144']
# ['2015', 'Tyrrell', '4219']
# ['2016', 'Tyrrell', '4133']
# ['2017', 'Tyrrell', '4304']
# ['2018', 'Tyrrell', '4260']
# ['2019', 'Tyrrell', '4259']
# ['Union', '202110', '204332', '207438', '210937', '215312', '219243', '223663', '228061', '232465', '237287']
# ['2010', 'Union', '202110']
# ['2011', 'Union', '204332']
# ['2012', 'Union', '207438']
# ['2013', 'Union', '210937']
# ['2014', 'Union', '215312']
# ['2015', 'Union', '219243']
# ['2016', 'Union', '223663']
# ['2017', 'Union', '228061']
# ['2018', 'Union', '232465']
# ['2019', 'Union', '237287']
# ['Vance', '45301', '45512', '45478', '44987', '44989', '45006', '44987', '45144', '45764', '45969']
# ['2010', 'Vance', '45301']
# ['2011', 'Vance', '45512']
# ['2012', 'Vance', '45478']
# ['2013', 'Vance', '44987']
# ['2014', 'Vance', '44989']
# ['2015', 'Vance', '45006']
# ['2016', 'Vance', '44987']
# ['2017', 'Vance', '45144']
# ['2018', 'Vance', '45764']
# ['2019', 'Vance', '45969']
# ['Wake', '906882', '924330', '944622', '963856', '983918', '1006139', '1028509', '1049943', '1070197', '1089579']
# ['2010', 'Wake', '906882']
# ['2011', 'Wake', '924330']
# ['2012', 'Wake', '944622']
# ['2013', 'Wake', '963856']
# ['2014', 'Wake', '983918']
# ['2015', 'Wake', '1006139']
# ['2016', 'Wake', '1028509']
# ['2017', 'Wake', '1049943']
# ['2018', 'Wake', '1070197']
# ['2019', 'Wake', '1089579']
# ['Warren', '20981', '21043', '20828', '20618', '20642', '20603', '20287', '20249', '20066', '20022']
# ['2010', 'Warren', '20981']
# ['2011', 'Warren', '21043']
# ['2012', 'Warren', '20828']
# ['2013', 'Warren', '20618']
# ['2014', 'Warren', '20642']
# ['2015', 'Warren', '20603']
# ['2016', 'Warren', '20287']
# ['2017', 'Warren', '20249']
# ['2018', 'Warren', '20066']
# ['2019', 'Warren', '20022']
# ['Washington', '13135', '13027', '12767', '12799', '12614', '12527', '12384', '12319', '12153', '12071']
# ['2010', 'Washington', '13135']
# ['2011', 'Washington', '13027']
# ['2012', 'Washington', '12767']
# ['2013', 'Washington', '12799']
# ['2014', 'Washington', '12614']
# ['2015', 'Washington', '12527']
# ['2016', 'Washington', '12384']
# ['2017', 'Washington', '12319']
# ['2018', 'Washington', '12153']
# ['2019', 'Washington', '12071']
# ['Watauga', '50967', '51742', '52439', '52664', '52963', '53780', '55142', '56294', '57067', '57899']
# ['2010', 'Watauga', '50967']
# ['2011', 'Watauga', '51742']
# ['2012', 'Watauga', '52439']
# ['2013', 'Watauga', '52664']
# ['2014', 'Watauga', '52963']
# ['2015', 'Watauga', '53780']
# ['2016', 'Watauga', '55142']
# ['2017', 'Watauga', '56294']
# ['2018', 'Watauga', '57067']
# ['2019', 'Watauga', '57899']
# ['Wayne', '122900', '124058', '125169', '125450', '125646', '125217', '125120', '124086', '124703', '125825']
# ['2010', 'Wayne', '122900']
# ['2011', 'Wayne', '124058']
# ['2012', 'Wayne', '125169']
# ['2013', 'Wayne', '125450']
# ['2014', 'Wayne', '125646']
# ['2015', 'Wayne', '125217']
# ['2016', 'Wayne', '125120']
# ['2017', 'Wayne', '124086']
# ['2018', 'Wayne', '124703']
# ['2019', 'Wayne', '125825']
# ['Wilkes', '69270', '69196', '69372', '69286', '69413', '69446', '69844', '69795', '69913', '70200']
# ['2010', 'Wilkes', '69270']
# ['2011', 'Wilkes', '69196']
# ['2012', 'Wilkes', '69372']
# ['2013', 'Wilkes', '69286']
# ['2014', 'Wilkes', '69413']
# ['2015', 'Wilkes', '69446']
# ['2016', 'Wilkes', '69844']
# ['2017', 'Wilkes', '69795']
# ['2018', 'Wilkes', '69913']
# ['2019', 'Wilkes', '70200']
# ['Wilson', '81285', '81273', '81314', '80929', '80866', '81217', '81483', '81597', '81949', '82282']
# ['2010', 'Wilson', '81285']
# ['2011', 'Wilson', '81273']
# ['2012', 'Wilson', '81314']
# ['2013', 'Wilson', '80929']
# ['2014', 'Wilson', '80866']
# ['2015', 'Wilson', '81217']
# ['2016', 'Wilson', '81483']
# ['2017', 'Wilson', '81597']
# ['2018', 'Wilson', '81949']
# ['2019', 'Wilson', '82282']
# ['Yadkin', '38434', '38343', '38269', '38160', '37850', '37730', '37828', '38140', '38100', '38196']
# ['2010', 'Yadkin', '38434']
# ['2011', 'Yadkin', '38343']
# ['2012', 'Yadkin', '38269']
# ['2013', 'Yadkin', '38160']
# ['2014', 'Yadkin', '37850']
# ['2015', 'Yadkin', '37730']
# ['2016', 'Yadkin', '37828']
# ['2017', 'Yadkin', '38140']
# ['2018', 'Yadkin', '38100']
# ['2019', 'Yadkin', '38196']
# ['Yancey', '17806', '17840', '17874', '17899', '17888', '17932', '18093', '18289', '18455', '18623']
# ['2010', 'Yancey', '17806']
# ['2011', 'Yancey', '17840']
# ['2012', 'Yancey', '17874']
# ['2013', 'Yancey', '17899']
# ['2014', 'Yancey', '17888']
# ['2015', 'Yancey', '17932']
# ['2016', 'Yancey', '18093']
# ['2017', 'Yancey', '18289']
# ['2018', 'Yancey', '18455']
# ['2019', 'Yancey', '18623']
# ['STATE', '9574293', '9656754', '9749123', '9843599', '9933944', '10033079', '10156679', '10270800', '10389148', '10508254']
# ['2010', 'STATE', '9574293']
# ['2011', 'STATE', '9656754']
# ['2012', 'STATE', '9749123']
# ['2013', 'STATE', '9843599']
# ['2014', 'STATE', '9933944']
# ['2015', 'STATE', '10033079']
# ['2016', 'STATE', '10156679']
# ['2017', 'STATE', '10270800']
# ['2018', 'STATE', '10389148']
# ['2019', 'STATE', '10508254']
# ['Source: North Carolina OSBM, Standard Population Estimates, Vintage 2018 and Population Projections, Vintage 2019', '', '', '', '', '', '', '', '', '', '']
# ['2010', 'Source: North Carolina OSBM, Standard Population Estimates, Vintage 2018 and Population Projections, Vintage 2019', '']
# ['2011', 'Source: North Carolina OSBM, Standard Population Estimates, Vintage 2018 and Population Projections, Vintage 2019', '']
# ['2012', 'Source: North Carolina OSBM, Standard Population Estimates, Vintage 2018 and Population Projections, Vintage 2019', '']
# ['2013', 'Source: North Carolina OSBM, Standard Population Estimates, Vintage 2018 and Population Projections, Vintage 2019', '']
# ['2014', 'Source: North Carolina OSBM, Standard Population Estimates, Vintage 2018 and Population Projections, Vintage 2019', '']
# ['2015', 'Source: North Carolina OSBM, Standard Population Estimates, Vintage 2018 and Population Projections, Vintage 2019', '']
# ['2016', 'Source: North Carolina OSBM, Standard Population Estimates, Vintage 2018 and Population Projections, Vintage 2019', '']
# ['2017', 'Source: North Carolina OSBM, Standard Population Estimates, Vintage 2018 and Population Projections, Vintage 2019', '']
# ['2018', 'Source: North Carolina OSBM, Standard Population Estimates, Vintage 2018 and Population Projections, Vintage 2019', '']
# ['2019', 'Source: North Carolina OSBM, Standard Population Estimates, Vintage 2018 and Population Projections, Vintage 2019', '']
# 17874
